# %%
consumo_diario = [ 50, 45, 55, 60, 48, 52, 47, 49, 53, 51, 50, 46, 54, 61, 49, 53, 48, 50, 52, 47, 56, 50, 55, 60,
                 48, 52, 47, 49, 53, 51]

# %%
def media_consumo(consumo_diario):
    total_consumo = sum(consumo_diario) 
    media = total_consumo/30
    return media

# %%
print(f"O consumo diário médio foi: {media_consumo(consumo_diario)}")
# Out:
# O consumo diário médio foi: 51.36666666666667
